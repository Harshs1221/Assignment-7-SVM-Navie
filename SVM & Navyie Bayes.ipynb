# %%
#Q1. What is a Support Vector Machine (SVM)?
"""
Ans1. A Support Vector Machine is a powerful supervised learning algorithm used for classification and
      regression.
      It works by finding the optimal hyperlane that best separates different classes in a dataset.
"""

# %%
#Q2. What is the difference between Hard Margin and Soft Margin SVM?
"""
Ans2. The difference between hard margin and soft margin are:
      1. Hard Margin SVM
          - Used when the data is perfectly separable.
          - It finds the maximum hyperplane without any misclassification.
          - Strict rule: Every data point must be correctly classified.
          - Limitation:
                If there's even a little noise or overlap between classes, Hard Margin SVM fails.
      2. Soft Margin SVM
          - Used when data is not perfectly separable.
          - Allows some misclassification to improve generalization.
          - More flexible: Works better with the real-world noisy data.
"""

# %%
#Q3. What is the mathematical intuition behind SVM?
"""
Ans3. The mathematical intution behind Support Vector Machines (SVM) revolves around fining the optimal 
      hyperplane that best separates different classes while maximizing the margin between them.

      1. Hyperplane Equation:
                  w.x + b = 0
            where w is the wight vector, x in the input vector and b is bias.
      2. Margin Maximization:
            SVM aims to maximize the margin between the hyperplane and closest data points. The margin is
            given by:
                                    2 / ||w||
            A larger margin leads to better generalization.
      
      3. Optimization Problem:
            SVM solves the following optimization problem:
                        min 𝑤,𝑏 1/2∣∣𝑤∣∣**2
            subject to the constraint:
                        yi(w.xi + b) >= 1                        
"""

# %%
#Q4.  What is the role of Lagrange Multipliers in SVM?
"""
Ans4. Lagrange helps SVM find the best dividing line between classes while hadnling constraints.
        Like:
            - SVM wants to maximize the margin between different classes.
            
            - But it also needs to respect the constraints (data must be correctly modified)
            
            - Lagrange Multipliers ast as a balancing tool- they help SVM find the best solution
              while keeping the constraints in check.
"""

# %%
#Q5. What are Support Vectors in SVM?
"""
Ans5. Support vectors are the key data points in a Support Vector Machine (SVM) that help define the 
      optimal hyperplane for classification.
      These are the closest points to the decision boundary and have a direct impact on its position.
"""

# %%
#Q6. What is a Support Vector Classifier (SVC)?
"""
Ans6. A Support Vector Classifier(SVC) is a type of Support vector Machine used for classificatio tasks. It finds
      the optimal hyperplane that separates different classes while maximizing the margin between them.
      - It works well with binaru and multi-class classification.
      - Uses support vector to define the decision boundary.
      - Can handle linear and non-linear classification using different kernels.
      - Uses regularization( C parameter) to control the trade-off between margin and misclassification.
"""

# %%
#Q7. What is a Support Vector Regressor (SVR)?
"""
Ans7. Support Vector Regressor is a type of Support Vector Machine used for regression tasks. It predict the 
      continous values by finding a hyperplane that best fits the data while minimizing errors.
      
      - Works well for linear and non-linear regression using different kernels (e.g., linear, polynomial,RBF)
      - Uses support vectors to define the best-fit function.
      - Introduces an epsilon-tube, meaning it ignores small errors within a certain range to improve 
        generalization.
      - uses regularization (C parameter) to control the trade-off between complexity and accuracy.
"""

# %%
#Q8.  What is the Kernel Trick in SVM?
"""
Ans8. The kernel trick in SVM helps solve problems where data is not linearly separable. 
      Instead of manually transforming the data into higher dimensional space, kernel function does this
      automatically, allowing SVM to find the better decision boundary.

      Types of Kernels:
          1. Linear - Better for simple, linearly separable data.
          2. Polynomial Kernel - Useful when data has curved patterns
          3. RBF(Radial Based Function) Kernel - Works well for complex datasets
"""

# %%
#Q9.  Compare Linear Kernel, Polynomial Kernel, and RBF Kernel.
"""
Ans9. Support vector machines use kernels to transform data into higher-dimensional spaces for better 
      classification.
      - Linear Kernel is best for simple, linearly separabel data.
      - Polynomial Kernal is useful when the decision boundary is corved.
      - RBF Kernel is most flexible, handling complex, non-linear data effectively.
"""

# %%
#Q10. What is the effect of the C parameter in SVM?
"""
Ans10. The C parameter in SVM controls the trade-off between maximizing the margin and minimizing 
       classification errors.

       Effect of C Parameter:

       1. Small C Value (Large Margin, More Misclassifications)
           - Allows more misclassified points in training.
           - Focuses on maximizing the margin rather than fitting every data point perfectly.
           - Leads to better generalization but may underfir if too small.
       
       2. Large C Value (Narrow Margin, Fewer Misclassification)
           - Tries to classify all training points correctly.
           - Leads to narrower margin, making the model more sensitive to noise.
           - Can overfit if too large, meaning it performs well on training data but poorly on new data.
"""

# %%
#Q11. What is the role of the Gamma parameter in RBF Kernel SVM?
"""
Ans11. The Gamma Parameter (y) in the RBF Kernel of SVM controls how much influence each data point has
       on the decision boundary.
       - Low Gamma (Small y) -
               Each point has a wide influence, leading to a smooth boundary. This helps in better 
               generalization but may underfit the data.
       - high Gamma (Large y) - 
               Each point has a narrow influence, making the boundary more complex. This can overfit the data,
               meaning it works well on training data but poorly on new data.
"""

# %%
#Q12. What is the Naïve Bayes classifier, and why is it called "Naïve"?
"""
Ans12. The Naive Bayes classifier is a probabilistic machine learning model based on Bayes' Theorem.
       It is widely used for classification tasks, such as spam filtering, sentiment analysis, and medical
       diagnosis.

       Why it is called Naive?
       The term "Naive" comes from the assumption that all features are independent of each other. In reality,
       this assumption is often not true, but it simplifies calculations and makes the model efficient.
"""

# %%
#Q13.  What is Bayes’ Theorem?
"""
Ans13. Bayes Theoram is a fundamental principle in probability theory that helps us update our beiefs
       based on new evidence.

       Mathematical Formula
                   𝑃(𝐴∣𝐵)= 𝑃(𝐵∣𝐴)𝑃(𝐴) / 𝑃(𝐵)
"""

# %%
#Q14.  Explain the differences between Gaussian Naïve Bayes, Multinomial Naïve Bayes, and Bernoulli Naïve Bayes.
"""
Ans14. Gaussian Naive Bayes:
        - Used for continous numerical data.
        - Assumes features follow a normal(Gaissian) distribution.
        - Example: Predicting whether a patient has diabetes based on contious features like
                   blood sugar level, and BMI.
       
       Multinomial Naive Bayes:
        - Used for text classification (word counts).
        - Assumes features represent word frequencies or counts.
        - Example: Spam detection - classifying emails as spam or not based on word occurences.

       Bernoulli Naive Bayes:
        - Used for binary data (0 to 1).
        - Assumes features are either present(1) or absent(0).
        - Example: Fraud detection - determining if a transaction is fraudlent based on binary
                   indicators like unusual location or large amount.
"""

# %%
#Q15. When should you use Gaussian Naïve Bayes over other variants.
"""
Ans15. Use Gaussian Naive Bayes when your data consists of continous numerical features that
       follow a normal distribution.

       When to use Gaussian Naive Byaes:
        1. When features are continous. like height, weight, temperature.
        2. When data follows a normal distribution bell curve.
        3. Fast & Efficient - Performs well with the small datasets.
"""

# %%
#Q16.  What are the key assumptions made by Naïve Bayes?
"""
Ans16. Naive Bayes makes two key assumption that simplify probability calculation for classifiation:

        1. Feature Independence Assumption:
            - It assumes that all features are independent given the class label.
            - Example: In spam detection, Naive bayes assumes that workd like "free" and "offer"
                       appear independently, even though they often occur together in spam emails.
              Reality: Features are often correlated, but this assumption , make computation efficient.
        
        2. Equal Contribution Assumption
            - It assumes that each feature contributes equally to the final classification.
            - Example: In a medical diagnosis model, Naive Bayes treats age and blood pressure
                       as equally important, even though some features may have more impact.
            - Reality: Some features are influential, But Naive bayes does not weigh them
                       differently.
"""

# %%
#Q17.  What are the advantages and disadvantages of Naïve Bayes?
"""
Ans17. Advantages:
        1. Based on probability 
                Uses Bayes Theorem to make predictions efficiently.
        2. Faster Algorithm
                Works well with large datasets, especially for text classification.
        3. Handle Small datasets
                Performs well even when training data is limited.
        4. effective for categorical data-
                Works great for tasks like spam detection and sentiment analysis.
       Disadvantages:
        1. Feature independence assumption -
                It assumes that the features are independent, which is often not true in real-world
                data
        2. Not ideal for complex relationships - 
                Doesn't capture correlations between features. 

"""

# %%
#Q18.  Why is Naïve Bayes a good choice for text classification?
"""
Ans18. Naive Bayes is good choice for text classification because of its simplicity, efficiency
       and effectiveness.

       1. Fast & Efficient: Works well with large datasets and require less training data.
       2. Handles High Dimensional Data:
               Txst data has many features(words), and Naive bayes can process them efficiently.
       3. Works Well with sparse Data - 
               In text classification, most words don't appear in every document, but Naive Bayes
               still performs well.
       4. Probabilistic Approach - 
               Uses bayes Therorem to calculate the probability of a documenr belonging to a categroy.
"""

# %%
#Q19. Compare SVM and Naïve Bayes for classification tasks.
"""
Ans19. Comparision of SVM and naive Bayes for Classification tasks are:

        1. Apporach: 
            - SVM finds a hyperplane that maximizes separation between classes.
            - Naive uses bayes theorem to calculate probabilities.
        2. Best for:
            - SVM Structured numerical data with complex relationships.
            - Naive Text and categorical data.
        3. Performance:
            - SVM Needs more training data for high accuracy
            - Naive works well with small datasets.
        4. Speed:
            - SVM slower due to complex optimization
            - Naive faster, especially for large datasets.
        5. Robust to Noise:
            - SVM sensitive to noise and outliers.
            - Naive Handles noisy data better
"""

# %%
#Q20.  How does Laplace Smoothing help in Naïve Bayes?
"""
Ans20. Leplace smoothing helps Naive Bayes by preventing zero probabilities when a word or feature does
       not appear in the training data.
       Without smoothing, if a word is missing from a class, its probability becomes zero, which can make 
       the entire classification fail.

       - it adds a small constant(usually 1) to all word counts.
       - This ensure that no probability is ever zero.

       Example:
           - If the word "discount" never appeared in spam emails during training, its probability 
             would be zero.
           - Without smoothing, any new email containing "discount" would never be classified as spam.
           - Laplace Smoothing ensures that even unseen words get a small probability, allowing better 
             prediction.
"""

# %% [markdown]
# ## Parctical Question

# %%
#Q21.  Write a Python program to train an SVM Classifier on the Iris dataset and evaluate accuracy.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
#Model evaluation
from sklearn.svm import SVC

# %%
cls =SVC(kernel = 'linear')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#prediction
y_pred = cls.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
#Q22. Write a Python program to train two SVM classifiers with Linear and RBF kernels on the Wine dataset, then 
#     compare their accuracies

# %%
from sklearn.datasets import load_wine

# %%
data= load_wine()

# %%
X = pd.DataFrame(data.data,columns=data.feature_names)
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
#Model evaluation linear kernel
from sklearn.svm import SVC

# %%
clslinear = SVC(kernel='linear')

# %%
clslinear.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#prediction
y_pred_lin = clslinear.predict(X_test)

# %%
#Model evaluation rbf kernel
from sklearn.svm import SVC

# %%
clsrbf = SVC(kernel='rbf')

# %%
clsrbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred_rbf = clsrbf.predict(X_test)

# %%
#Accuracy score
lin = accuracy_score(y_test, y_pred_lin)
rbf = accuracy_score(y_test, y_pred_rbf)

# %%
print(f'Accuracy score kernel linear is {lin:.2f}')
print(f'Accuracy score kernel rbf is {rbf:.2f}')
# Out:
# Accuracy score kernel linear is 0.94
# Accuracy score kernel rbf is 0.64

# %%
#Q23.  Write a Python program to train an SVM Regressor (SVR) on a housing dataset and evaluate it using Mean Squared Error (MSE).
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
X = pd.DataFrame(data.data, columns= data.feature_names)
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVR

# %%
model = SVR()

# %%
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 1.3207323835269855

# %%
#Q24.  Write a Python program to train an SVM Classifier with a Polynomial Kernel and visualize the decision boundary.

# %%
X, y = make_classification(n_samples=200, n_features=2, n_classes=2,n_redundant=0,n_informative=2, n_clusters_per_class=1, random_state=1)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC

# %%
cls = SVC(kernel='poly', degree = 3)

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
x_min, x_max = X[:,0].min() -1, X[:,0].max() +1
y_min, y_max = X[:,1].min() -1, X[:,1].max() +1

# %%
xx, yy = np.meshgrid(np.linspace(x_min, x_max , 100), np.linspace(y_min, y_max, 100))

# %%
xx = np.array(xx)  # Convert xx to a NumPy array
yy = np.array(yy)

# %%
Z = cls.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
plt.contourf(xx, yy, Z, alpha = 0.3)
plt.scatter(X[:,0], X[:,1], c = y)
plt.show()

# %%
#Q25.  Write a Python program to train a Gaussian Naïve Bayes classifier on the Breast Cancer dataset and evaluate accuracy
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %%
X=pd.DataFrame(data.data, columns= data.feature_names)
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
cls = GaussianNB()

# %%
cls
# Out:
# GaussianNB()

# %%
cls.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#prediction
y_pred = cls.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(f"accuracy " ,accuracy_score(y_test, y_pred))
# Out:
# accuracy  0.9473684210526315

# %%
#Q26.  Write a Python program to train a Multinomial Naïve Bayes classifier for text classification using the 20 Newsgroups dataset.
from sklearn.datasets import fetch_20newsgroups

# %%
data= fetch_20newsgroups(subset='all', categories=None)

# %%
X = data.data

# %%
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer  #for counting the word and tfid is for checking weightage of words

# %%
model = make_pipeline(CountVectorizer(), TfidfTransformer(), MultinomialNB() )

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8382677861246134

# %%
#Q27. Write a Python program to train an SVM Classifier with different C values and compare the decision boundaries visually

# %%
X, y = make_classification(n_samples=200, n_features=2, n_classes=2,n_redundant=0,n_informative=2, n_clusters_per_class=1, random_state=1)

# %%
#train test split
X_train,X_test, y_train,  y_test =  train_test_split(X, y, test_size=0.2, random_state=1)

# %%
C_value = [0.1, 1, 10]

# %%
fig, axes = plt.subplots(1, len(C_value), figsize=(15,6))

# %%
# Model Training
for i, C in enumerate(C_value):
    model = SVC(kernel='linear', C=C)
    model.fit(X_train, y_train)
    #compute decision boundary
    w = model.coef_[0]
    a = -w[0] / w[1]
    xx = np.linspace(X[:, 0].min() -1, X[:,0].max() +1, 100)
    yy = a * xx - (model.intercept_[0] / w[1])

    sns.scatterplot(x= X_test[:,0], y= X_test[:,1], hue = y_test, ax = axes[i])
    axes[i].plot(xx,yy, color = 'red')
    axes[i].set_title(f"SVM Decision boundary (C = {C})")
plt.tight_layout()
plt.show()

# %%
#Q28. Write a Python program to train a Bernoulli Naïve Bayes classifier for binary classification on a dataset with 
#     binary features

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples= 1000, n_features=10, n_classes=2, n_informative=5, n_clusters_per_class=1, random_state=1)

# %%
#covert features to binary (0 to 1)
X_binary =  np.where(X > np.mean(X), 1,0)

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test, y_train, y_test = train_test_split(X_binary, y, test_size=0.2, random_state=1)

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
model = BernoulliNB()

# %%
model.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %%
#prediction
y_pred = model.predict(X_test)

# %%
#accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
#Q29. Write a Python program to apply feature scaling before training an SVM model and compare results with 
#     unscaled data

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
X = pd.DataFrame(data.data, columns= data.feature_names)
y = data.target

# %%
#train test split
X_train,X_test, y_train, y_test =  train_test_split(X, y , test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC

# %%
cls = SVC(kernel = 'linear')

# %%
cls
# Out:
# SVC(kernel='linear')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#make prediction
y_pred = cls.predict(X_test)

# %%
acc= accuracy_score(y_test, y_pred)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
model_scaled =  SVC(kernel='linear')

# %%
model_scaled.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_scaled = model_scaled.predict(X_test_scaled)

# %%
#accuracy score
acc_scale = accuracy_score(y_test, y_pred_scaled)

# %%
#comparision
print(f'Accuracy score for unscaled data {acc}')
print(f'Accuracy score for scaled data {acc_scale:.2f}')
# Out:
# Accuracy score for unscaled data 1.0
# Accuracy score for scaled data 0.97

# %%
#Q30. Write a Python program to train a Gaussian Naïve Bayes model and compare the predictions before and 
#     after Laplace Smoothing.

# %%
X, y = make_classification(n_samples=200, n_features=10, n_clusters_per_class=1, n_classes=2, n_informative=5, random_state=1)

# %%
#split the data into train test split
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2, random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model =  GaussianNB()

# %%
model
# Out:
# GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#make prediction 
y_pred  = model.predict(X_test)

# %%
acwithout_smothing = accuracy_score(y_test, y_pred)

# %%
#with laplace smoothing
mo_smoothing = GaussianNB(var_smoothing= 1e-2)

# %%
mo_smoothing
# Out:
# GaussianNB(var_smoothing=0.01)

# %%
mo_smoothing.fit(X_train,y_train)
# Out:
# GaussianNB(var_smoothing=0.01)

# %%
y_pred_smoothing = mo_smoothing.predict(X_test)

# %%
ac_smoothing = accuracy_score(y_test, y_pred_smoothing)

# %%
print(f"Accuracy score without Lappace Smoothing {acwithout_smothing}")
print(f"Accuracy score after Lappace Smoothing {ac_smoothing}")
# Out:
# Accuracy score without Lappace Smoothing 0.95
# Accuracy score after Lappace Smoothing 0.925

# %%
#Q31.  Write a Python program to train an SVM Classifier and use GridSearchCV to tune the hyperparameters (C, gamma, kernel)
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=200, n_features=10, n_clusters_per_class=1, n_classes=2, n_informative=5, random_state=1)

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=1)

# %%
X_train.shape, y_train.shape
# Out:
# ((140, 10), (140,))

# %%
params = {
    'C': [0.1, 1, 10, 100],
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['linear', 'rbf', 'poly']
}

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
cls = SVC()

# %%
grid_model = GridSearchCV(cls, param_grid=params)

# %%
grid_model
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
grid_model.best_params_
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
clf = SVC(C=1, gamma=0.1, kernel='rbf')

# %%
clf
# Out:
# SVC(C=1, gamma=0.1)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=0.1)

# %%
#make prediction
y_pred = clf.predict(X_test)

# %%
ac = accuracy_score(y_test, y_pred)
print(f"Accuracy with best parameter are {ac:.2f}")
# Out:
# Accuracy with best parameter are 0.98

# %%
#Q32.  Write a Python program to train an SVM Classifier on an imbalanced dataset and apply class weighting and check it 
    #  improve accuracy.

# %%
X, y = make_classification(n_samples=1000, n_features= 10, n_classes=2, weights=[0.9,0.1], random_state=1)

# %%
#split the data into train test split
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.2, random_state=1)

# %%
#without class weighting
from sklearn.svm import SVC

# %%
model = SVC(kernel='linear')

# %%
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#make prediction
y_pred = model.predict(X_test)

# %%
ac= accuracy_score(y_test, y_pred)

# %%
#with weighting
model_weighting = SVC(kernel="linear", class_weight="balanced")

# %%
model_weighting.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear')

# %%
#make prediction
y_pred = model_weighting.predict(X_test)

# %%
ac_weighting = accuracy_score(y_test, y_pred)

# %%
print(f"Accuracy score without weighting {ac}")
print(f"Accuracy score with weighting {ac_weighting}")
# Out:
# Accuracy score without weighting 0.92
# Accuracy score with weighting 0.855

# %%
#Q33.  Write a Python program to implement a Naïve Bayes classifier for spam detection using email data.

# %%
df = pd.read_csv("spam_ham_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
X = df['text']
y = df['label_num']

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.3, random_state=1)

# %%
X_train.shape, y_train.shape
# Out:
# ((3619,), (3619,))

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB

# %%
model = make_pipeline(CountVectorizer(), TfidfTransformer(), MultinomialNB())

# %%
model
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('countvectorizer', CountVectorizer()),
#                 ('tfidftransformer', TfidfTransformer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
#make prediction
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8769329896907216

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1101
#            1       1.00      0.58      0.73       451
#
#     accuracy                           0.88      1552
#    macro avg       0.92      0.79      0.83      1552
# weighted avg       0.89      0.88      0.87      1552

# %%
#Q34. Write a Python program to train an SVM Classifier and a Naïve Bayes Classifier on the same dataset and compare their accuracy 
from sklearn.datasets import load_iris
import pandas as pd

# %%
data = load_iris()

# %%
X  = pd.DataFrame(data.data, columns = data.feature_names)
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.3, random_state=1)

# %%
#SVM classifier
from sklearn.svm import SVC
cls_svm = SVC(kernel = 'linear')

# %%
cls_svm
# Out:
# SVC(kernel='linear')

# %%
cls_svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#make prediction
y_pred_svm = cls_svm.predict(X_test)

# %%
ac_svc = accuracy_score(y_test, y_pred_svm)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nv_model = GaussianNB()

# %%
nv_model
# Out:
# GaussianNB()

# %%
nv_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#make preduction
y_pred = nv_model.predict(X_test)

# %%
nv_ac = accuracy_score(y_test, y_pred)

# %%
print(f'Accuracy score for SVM classifier is {ac_svc}')
print(f'Accuracy score for Naive bayes classifier is {nv_ac:.2f}')
# Out:
# Accuracy score for SVM classifier is 1.0
# Accuracy score for Naive bayes classifier is 0.93

# %%
#Q35. Write a Python program to perform feature selection before training a Naïve Bayes classifier and compare results.
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.3, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_sclaed = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#feature selection using lasso
from sklearn.linear_model import Lasso

# %%
laso = Lasso(alpha=0.1)

# %%
laso.fit(X_train_sclaed, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
#drop the zero coefficients feature  
laso_selected = laso.coef_ != 0

# %%
X_train_selected = X_train[:,laso_selected]

# %%
X_test_selected = X_test[:, laso_selected]

# %%
#train naive bayes without feature selection
nb_full = GaussianNB()

# %%
nb_full
# Out:
# GaussianNB()

# %%
nb_full.fit(X_train_sclaed, y_train)
# Out:
# GaussianNB()

# %%
#Make prediction
y_pred = nb_full.predict(X_test_scaled)

# %%
ac_full = accuracy_score(y_test, y_pred)

# %%
ac_full
# Out:
# 0.9466666666666667

# %%
#train naive bayes with feature selection
nb_selected = GaussianNB()

# %%
nb_selected.fit(X_train_selected, y_train)
# Out:
# GaussianNB()

# %%
#Make prediction
y_pred_selected = nb_selected.predict(X_test_selected)

# %%
ac_selected = accuracy_score(y_test, y_pred_selected)

# %%
print(f"Accuracy score without feature selection {ac_full:.2f}")
print(f"Accuracy score with feature selection {ac_selected:.2f}")
# Out:
# Accuracy score without feature selection 0.95
# Accuracy score with feature selection 0.93

# %%
#Q36.  Write a Python program to train an SVM Classifier using One-vs-Rest (OvR) and One-vs-One (OvO) 
#      strategies on the Wine dataset and compare their accuracy
from sklearn.datasets import load_wine

# %%
data = load_wine()

# %%
X = pd.DataFrame(data.data, columns= data.feature_names)
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size= 0.2, random_state=1)

# %%
from sklearn.svm import SVC

# %%
#One Vs rest
cls = SVC(kernel = 'linear', decision_function_shape= 'ovr')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#make prediction 
y_pred = cls.predict(X_test)

# %%
ac_ovr = accuracy_score(y_test, y_pred)
ac_ovr
# Out:
# 0.9444444444444444

# %%
# One vs One
cls_ovo = SVC(kernel='linear', decision_function_shape= 'ovo')

# %%
cls_ovo
# Out:
# SVC(decision_function_shape='ovo', kernel='linear')

# %%
cls_ovo.fit(X_train, y_train)
# Out:
# SVC(decision_function_shape='ovo', kernel='linear')

# %%
#make prediction
y_pred_ovo = cls_ovo.predict(X_test)

# %%
ac_ovo = accuracy_score(y_test, y_pred_ovo)

# %%
print(f"Accuracy score using One-vs-rest {ac_ovr:.2f}")
print(f"Accuracy score using One-vs-one {ac_ovo:.2f}")
# Out:
# Accuracy score using One-vs-rest 0.94
# Accuracy score using One-vs-one 0.94

# %%
#Q37. Write a Python program to train an SVM Classifier using Linear, Polynomial, and RBF kernels on the Breast 
#     Cancer dataset and compare their accuracy

# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %%
X = pd.DataFrame(data.data, columns = data.feature_names)
y = data.target

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVC
lin_cls = SVC(kernel = 'linear')

# %%
lin_cls
# Out:
# SVC(kernel='linear')

# %%
lin_cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_lin = lin_cls.predict(X_test)

# %%
ac_lin = accuracy_score(y_test, y_pred_lin)

# %%
#kernel polynomial
cls_poly = SVC(kernel = 'poly')

# %%
cls_poly.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
#make prediction
y_pred_poly = cls_poly.predict(X_test)

# %%
ac_poly = accuracy_score(y_test, y_pred_poly)

# %%
#kernel polynomial
cls_rbf = SVC(kernel = 'rbf')

# %%
cls_rbf.fit(X_train, y_train)
# Out:
# SVC()

# %%
#make prediction
y_pred_rbf = cls_rbf.predict(X_test)

# %%
ac_rbf = accuracy_score(y_test, y_pred_rbf)

# %%
print(f"Accuray score of SVm classifier kernel is linear {ac_lin:.2f}")
print(f"Accuray score of SVm classifier kernel is polynomial {ac_poly:.2f}")
print(f"Accuray score of SVm classifier kernel is rbf {ac_rbf:.2f}")
# Out:
# Accuray score of SVm classifier kernel is linear 0.96
# Accuray score of SVm classifier kernel is polynomial 0.89
# Accuray score of SVm classifier kernel is rbf 0.90

# %%
#Q38. Write a Python program to train an SVM Classifier using Stratified K-Fold Cross-Validation and compute the 
#     average accuracy

# %%
from sklearn.datasets import load_wine

# %%
data = load_wine()

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
skf = StratifiedKFold(n_splits=5, shuffle= True, random_state=1)

# %%
svm_model = SVC(kernel='linear')

# %%
svm_model
# Out:
# SVC(kernel='linear')

# %%
score = cross_val_score(svm_model, X,y, scoring = 'accuracy', cv = skf)

# %%
average_accuracy = np.mean(score)

# %%
average_accuracy
# Out:
# 0.9495238095238095

# %%
#Q39. Write a Python program to train a Naïve Bayes classifier using different prior probabilities and compare performance.
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
#model training
model = GaussianNB()

# %%
model
# Out:
# GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#predtion
y_pred = model.predict(X_test)

# %%
ac = accuracy_score(y_test, y_pred)

# %%
custom_prior = [0.7, 0.3]

# %%
cust_model = GaussianNB(priors= custom_prior)

# %%
cust_model
# Out:
# GaussianNB(priors=[0.7, 0.3])

# %%
cust_model.fit(X_train, y_train)
# Out:
# GaussianNB(priors=[0.7, 0.3])

# %%
#make prediction
y_pred_cust = cust_model.predict(X_test)

# %%
ac_cust = accuracy_score(y_test, y_pred_cust)

# %%
print(f"Accuracy socre with default model {ac}")
print(f"Accuracy score using prior probabilitoes {ac_cust} ")
# Out:
# Accuracy socre with default model 0.96
# Accuracy score using prior probabilitoes 0.95

# %%
#Q40.  Write a Python program to perform Recursive Feature Elimination (RFE) before training an SVM Classifier and compare accuracy.
data = load_wine()

# %%
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
#train model withour feature selection
cls = SVC(kernel='linear')

# %%
cls
# Out:
# SVC(kernel='linear')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
#make prediction
y_pred = cls.predict(X_test)

# %%
ac = accuracy_score(y_test, y_pred)

# %%
#model with REF
from sklearn.feature_selection import RFE

# %%
rfe = RFE(estimator = SVC(kernel='linear'), n_features_to_select=5)

# %%
rfe
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=5)

# %%
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=5)

# %%
#make prediction
y_pred_rfe = rfe.predict(X_test)

# %%
acc_rfe = accuracy_score(y_test, y_pred_rfe)

# %%
print(f' Accuracy score without feature selection {ac:.2f}')
print(f' Accuracy score with feature selection {acc_rfe:.2f}')
# Out:
#  Accuracy score without feature selection 0.94
#  Accuracy score with feature selection 0.97

# %%
#Q41. Write a Python program to train an SVM Classifier and evaluate its performance using Precision, Recall, and 
#     F1-Score instead of accuracy

# %%
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
cls = SVC(kernel='linear')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = cls.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.93

# %%
from sklearn.metrics import recall_score, precision_score, f1_score
print(f"Recall score is", recall_score(y_test, y_pred))
print(f'Precision score is', precision_score(y_test, y_pred))
print(f'F1 score is', f1_score(y_test, y_pred))
# Out:
# Recall score is 0.9534883720930233
# Precision score is 0.8913043478260869
# F1 score is 0.9213483146067416

# %%
#Q42. Write a Python program to train a Naïve Bayes Classifier and evaluate its performance using Log Loss (Cross-Entropy Loss).

# %%
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import log_loss
log_loss(y_test, y_pred)
# Out:
# 1.4417461355646861

# %%
#Q43. Write a Python program to train an SVM Classifier and visualize the Confusion Matrix using seaborn

# %%
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
cls = SVC(kernel='linear')

# %%
cls.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = cls.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[52,  5],
#        [ 2, 41]], dtype=int64)

# %%
sns.heatmap(cm, cmap='Blues', fmt='d')
plt.xlabel("Predicted labels")
plt.ylabel("Actual Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
#Q44. Write a Python program to train an SVM Regressor (SVR) and evaluate its performance using Mean Absolute 
#     Error (MAE) instead of MSE
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=500, n_features=5, noise = 5 , random_state=1)

# %%
#train test split
X_train,X_test,  y_train,y_test =  train_test_split(X, y , test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVR

# %%
svr_model = SVR(kernel='rbf')

# %%
svr_model
# Out:
# SVR()

# %%
svr_model.fit(X_train, y_train)
# Out:
# SVR()

# %%
#make prediction
y_pred_svr = svr_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 87.4421431540292

# %%
#Q45.  Write a Python program to train a Naïve Bayes classifier and evaluate its performance using the ROC-AUC score.

# %%
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_prob = model.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, y_prob)
# Out:
# 0.9914320685434516

# %%
#Q46.  Write a Python program to train an SVM Classifier and visualize the Precision-Recall Curve.

# %%
X, y = make_classification(n_samples=500, n_features=20, n_classes=2, random_state=1)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
model = SVC(kernel='linear', probability=True)

# %%
model.fit(X_train , y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y_pred_proba = model.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)

# %%
av_pre = average_precision_score(y_test, y_pred_proba)

# %%
plt.plot( recall, precision, marker = '.', label = f'AP = {av_pre:.2f}')
plt.xlabel("Recall ")
plt.ylabel("Precision")
plt.title("Precision Recall Curve")
plt.legend()
plt.show()
